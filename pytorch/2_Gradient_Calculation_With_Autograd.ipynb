# %% [markdown]
# ## Specifying a tensor requires gradient calculation

# %%
import torch

# %%
# Creating a tensor and setting the 'requires_grad' kwarg to 'True'
x = torch.randn(3,3, requires_grad=True)

# %%
x
# Out:
# tensor([[-1.6616, -0.4671,  1.8359],
#         [ 0.6629,  0.0065,  0.7508],
#         [-0.3053,  0.1200, -1.5428]], requires_grad=True)

# %%
# Because we set the 'requires_grad' kwarg to 'True', Pytorch will save a function

# %% [markdown]
# # 5.1. Gradient Descent Manually with Numpy

# %%
import numpy as np

# %% [markdown]
# ## Function : y = w * x

# %%
# f = w * x

# f = 2 * x

X = np.array([i+1 for i in range(4)], dtype=np.float32)
Y = np.array([i*2+2 for i in range(4)], dtype=np.float32)
Y, X
# Out:
# (array([2., 4., 6., 8.], dtype=float32),
#  array([1., 2., 3., 4.], dtype=float32))

# %% [markdown]
# ### Intialize the model parameter

# %%
w = 0.0

# %% [markdown]
# ## Model prediction

# %% [markdown]
# ### Define the forward function, the loss and the gradient

# %%
# model prediction
def forward(x):
    return w * x 

# loss : MSE
def loss(y, y_predicted):
    return ((y_predicted -y)**2).mean()

# gradients
# MSE : 1/N (w*x - y)**2
# dJ/dw : 1/N 2*x (w*y - y)
def gradient(x, y, y_predicted):
    return np.dot(2*x, y_predicted-y).mean()

print(f"Prediction before training f(5) = {forward(5)}")
# Out:
# Prediction before training f(5) = 0.0

# %% [markdown]
# ### Train the model : the model fails when the X, Y vectors are larger than 5 elements

# %%
# Training
learning_rate = 0.01
n_iters = 10

for epoch in range(n_iters):
    # prediction = forward pass
    y_pred = forward(X)

    # loss
    l = loss(Y, y_pred)

    # gradient
    dw = gradient(X, Y, y_pred)

    # update weights
    w -= learning_rate * dw

    if epoch % 2 == 0:
        print(f" epoch {epoch + 1} : w = {w:.3f}, loss = {l:.12f}")

print(f"Prediction after training f(5) = {forward(5)}")
# Out:
#  epoch 1 : w = 2.000, loss = 0.000000072173
#  epoch 3 : w = 2.000, loss = 0.000000001857
#  epoch 5 : w = 2.000, loss = 0.000000000047
#  epoch 7 : w = 2.000, loss = 0.000000000001
#  epoch 9 : w = 2.000, loss = 0.000000000000
# Prediction after training f(5) = 9.99999995231629
